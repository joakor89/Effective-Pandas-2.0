# %% [markdown]
# # Series Deep Dive
#
# ### Loading Libraries

# %%
# Numerical Computing
import numpy as np

# Data Manipulation
import pandas as pd

# PyArrow
import pyarrow as pa

# %% [markdown]
# ### Loading Data

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/' \
      'vehicles.csv.zip'

# %%
df = pd.read_csv(url,
                 dtype_backend='pyarrow',
                 engine='pyarrow')

# %%
city_mpg = df.city08

# %%
highway_mpg = df.highway08

# %%
city_mpg
# Out:
# 0        19
# 1         9
# 2        23
# 3        10
# 4        17
#          ..
# 41139    19
# 41140    20
# 41141    18
# 41142    18
# 41143    16
# Name: city08, Length: 41144, dtype: int64[pyarrow]

# %%
highway_mpg
# Out:
# 0        25
# 1        14
# 2        33
# 3        12
# 4        23
#          ..
# 41139    26
# 41140    28
# 41141    24
# 41142    24
# 41143    21
# Name: highway08, Length: 41144, dtype: int64[pyarrow]

# %% [markdown]
# ### Series Attributes

# %%
# Checking Length-Up
len(dir(city_mpg))
# Out:
# 391

# %% [markdown]
# # Operators & (`Dunder Methods`)
#
# ### Dunder Methods

# %%
2 + 4
# Out:
# 6

# %%
(city_mpg + highway_mpg) / 2
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 41139    22.5
# 41140    24.0
# 41141    21.0
# 41142    21.0
# 41143    18.5
# Length: 41144, dtype: double[pyarrow]

# %% [markdown]
# ### Index Alignment

# %%
s1 = pd.Series([10, 20, 30], index=[1, 2, 2])

s2 = pd.Series([35, 44, 53], index=[2, 2, 4], name='s2')

# %%
s1
# Out:
# 1    10
# 2    20
# 2    30
# dtype: int64

# %%
s2
# Out:
# 2    35
# 2    44
# 4    53
# Name: s2, dtype: int64

# %%
s1 + s2
# Out:
# 1     NaN
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4     NaN
# dtype: float64

# %% [markdown]
# ### Broadcasting

# %%
s2 + 5
# Out:
# 2    40
# 2    49
# 4    58
# Name: s2, dtype: int64

# %% [markdown]
# ### Operators Methods

# %%
s1 + s2
# Out:
# 1     NaN
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4     NaN
# dtype: float64

# %%
s1.add(s2)
# Out:
# 1     NaN
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4     NaN
# dtype: float64

# %%
s1.add(s2, fill_value=0)
# Out:
# 1    10.0
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4    53.0
# dtype: float64

# %% [markdown]
# ### Chaining

# %%
((city_mpg +
  highway_mpg)
 / 2
)
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 41139    22.5
# 41140    24.0
# 41141    21.0
# 41142    21.0
# 41143    18.5
# Length: 41144, dtype: double[pyarrow]

# %%
(city_mpg
 .add(highway_mpg)
 .div(2)
)
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 41139    22.5
# 41140    24.0
# 41141    21.0
# 41142    21.0
# 41143    18.5
# Length: 41144, dtype: double[pyarrow]

# %% [markdown]
# # Aggregate Methods
#
# ### Aggregations

# %%
city_mpg.mean()
# Out:
# 18.369045304297103

# %%
city_mpg.is_unique
# Out:
# False

# %%
city_mpg.is_monotonic_increasing
# Out:
# False

# %%
city_mpg.quantile()
# Out:
# 17.0

# %%
city_mpg.quantile(.9)
# Out:
# 24.0

# %%
city_mpg.quantile([.1, .5, .9])
# Out:
# 0.1    13.0
# 0.5    17.0
# 0.9    24.0
# Name: city08, dtype: double[pyarrow]

# %% [markdown]
# ### Count & Mean of Attribute

# %%
(city_mpg
 .gt(20)
 .sum()
)
# Out:
# 10272

# %%
# (city_mpg
#  .gt(20)
#  .mul(100)
#  .mean()
# )

# %%
(city_mpg
    .gt(20)
    .astype("int64[pyarrow]")   # True/False -> 1/0 en Arrow
    .mul(100)
    .mean()
)
# Out:
# 24.965973167412017

# %% [markdown]
# ### `.agg` & Aggreation Strings

# %%
city_mpg.agg('mean')
# Out:
# 18.369045304297103

# %%
def second_to_last(s):
    return s.iloc[-2]

# %%
city_mpg.agg(['mean', np.var, max, second_to_last])
# Out:
# mean               18.369045
# var                62.501517
# max               150.000000
# second_to_last     18.000000
# Name: city08, dtype: float64

# %% [markdown]
# # Conversion Methods
#
# ### Type Conversion

# %%
city_mpg.astype('int16[pyarrow]')
# Out:
# 0        19
# 1         9
# 2        23
# 3        10
# 4        17
#          ..
# 41139    19
# 41140    20
# 41141    18
# 41142    18
# 41143    16
# Name: city08, Length: 41144, dtype: int16[pyarrow]

# %%
city_mpg.astype('int8[pyarrow]')
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 city_mpg.astype('int8[pyarrow]')
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/internals/managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/internals/managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     178     return values
#     180 if not isinstance(values, np.ndarray):
#     181     # i.e. ExtensionArray
# --> 182     values = values.astype(dtype, copy=copy)
#     184 else:
#     185     values = _astype_nansafe(values, dtype, copy=copy)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/arrays/base.py:816, in ExtensionArray.astype(self, dtype, copy)
#     814 if isinstance(dtype, ExtensionDtype):
#     815     cls = dtype.construct_array_type()
# --> 816     return cls._from_sequence(self, dtype=dtype, copy=copy)
#     818 elif lib.is_np_dtype(dtype, "M"):
#     819     from pandas.core.arrays import DatetimeArray
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py:333, in ArrowExtensionArray._from_sequence(cls, scalars, dtype, copy)
#     329 """
#     330 Construct a new ExtensionArray from a sequence of scalars.
#     331 """
#     332 pa_type = to_pyarrow_type(dtype)
# --> 333 pa_array = cls._box_pa_array(scalars, pa_type=pa_type, copy=copy)
#     334 arr = cls(pa_array)
#     335 return arr
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py:704, in ArrowExtensionArray._box_pa_array(cls, value, pa_type, copy)
#     702 else:
#     703     try:
# --> 704         pa_array = pa_array.cast(pa_type)
#     705     except (pa.ArrowNotImplementedError, pa.ArrowTypeError):
#     706         if pa.types.is_string(pa_array.type) or pa.types.is_large_string(
#     707             pa_array.type
#     708         ):
#     709             # TODO: Move logic in _from_sequence_of_strings into
#     710             # _box_pa_array
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/table.pxi:597, in pyarrow.lib.ChunkedArray.cast()
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/compute.py:412, in cast(arr, target_type, safe, options, memory_pool)
#     410     else:
#     411         options = CastOptions.safe(target_type)
# --> 412 return call_function("cast", [arr], options, memory_pool)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/_compute.pyx:604, in pyarrow._compute.call_function()
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/_compute.pyx:399, in pyarrow._compute.Function.call()
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: Integer value 132 not in range: -128 to 127

# %%
np.iinfo('int64')
# Out:
# iinfo(min=-9223372036854775808, max=9223372036854775807, dtype=int64)

# %%
np.iinfo('int8')
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
# np.finfo('int32')

# %% [markdown]
# ### Memory Usage

# %%
city_mpg.nbytes
# Out:
# 329152

# %%
city_mpg.astype('Int16').nbytes
# Out:
# 123432

# %%
make = df.make

# %%
make.nbytes
# Out:
# 425635

# %%
make.memory_usage()
# Out:
# 425767

# %%
make.memory_usage(deep=True)
# Out:
# 425767

# %%
make.astype(str).memory_usage()
# Out:
# 590343

# %%
make.astype(str).memory_usage(deep=True)
# Out:
# 590343

# %% [markdown]
# ### String & Category Types

# %%
(make
 .astype('category')
 .memory_usage(deep=True)
)
# Out:
# 84533
