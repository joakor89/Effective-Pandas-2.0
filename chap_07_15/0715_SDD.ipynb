# %% [markdown]
# # Series Deep Dive
#
# ### Loading Libraries

# %%
# Numerical Computing
import math
import numpy as np

# Data Manipulation
import pandas as pd

# PyArrow
import pyarrow as pa

# %% [markdown]
# ### Loading Data

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/' \
      'vehicles.csv.zip'

# %%
df = pd.read_csv(url,
                 dtype_backend='pyarrow',
                 engine='pyarrow')

# %%
city_mpg = df.city08

# %%
highway_mpg = df.highway08

# %%
city_mpg
# Out:
# 0        19
# 1         9
# 2        23
# 3        10
# 4        17
#          ..
# 41139    19
# 41140    20
# 41141    18
# 41142    18
# 41143    16
# Name: city08, Length: 41144, dtype: int64[pyarrow]

# %%
highway_mpg
# Out:
# 0        25
# 1        14
# 2        33
# 3        12
# 4        23
#          ..
# 41139    26
# 41140    28
# 41141    24
# 41142    24
# 41143    21
# Name: highway08, Length: 41144, dtype: int64[pyarrow]

# %% [markdown]
# ### Series Attributes

# %%
# Checking Length-Up
len(dir(city_mpg))
# Out:
# 420

# %% [markdown]
# # Operators & (`Dunder Methods`)
#
# ### Dunder Methods

# %%
2 + 4
# Out:
# 6

# %%
(city_mpg + highway_mpg) / 2
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 41139    22.5
# 41140    24.0
# 41141    21.0
# 41142    21.0
# 41143    18.5
# Length: 41144, dtype: double[pyarrow]

# %% [markdown]
# ### Index Alignment

# %%
s1 = pd.Series([10, 20, 30], index=[1, 2, 2])

s2 = pd.Series([35, 44, 53], index=[2, 2, 4], name='s2')

# %%
s1
# Out:
# 1    10
# 2    20
# 2    30
# dtype: int64

# %%
s2
# Out:
# 2    35
# 2    44
# 4    53
# Name: s2, dtype: int64

# %%
s1 + s2
# Out:
# 1     NaN
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4     NaN
# dtype: float64

# %% [markdown]
# ### Broadcasting

# %%
s2 + 5
# Out:
# 2    40
# 2    49
# 4    58
# Name: s2, dtype: int64

# %% [markdown]
# ### Operators Methods

# %%
s1 + s2
# Out:
# 1     NaN
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4     NaN
# dtype: float64

# %%
s1.add(s2)
# Out:
# 1     NaN
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4     NaN
# dtype: float64

# %%
s1.add(s2, fill_value=0)
# Out:
# 1    10.0
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4    53.0
# dtype: float64

# %% [markdown]
# ### Chaining

# %%
((city_mpg +
  highway_mpg)
 / 2
)
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 41139    22.5
# 41140    24.0
# 41141    21.0
# 41142    21.0
# 41143    18.5
# Length: 41144, dtype: double[pyarrow]

# %%
(city_mpg
 .add(highway_mpg)
 .div(2)
)
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 41139    22.5
# 41140    24.0
# 41141    21.0
# 41142    21.0
# 41143    18.5
# Length: 41144, dtype: double[pyarrow]

# %% [markdown]
# # Aggregate Methods
#
# ### Aggregations

# %%
city_mpg.mean()
# Out:
# 18.369045304297103

# %%
city_mpg.is_unique
# Out:
# False

# %%
city_mpg.is_monotonic_increasing
# Out:
# False

# %%
city_mpg.quantile()
# Out:
# 17.0

# %%
city_mpg.quantile(.9)
# Out:
# 24.0

# %%
city_mpg.quantile([.1, .5, .9])
# Out:
# 0.1    13.0
# 0.5    17.0
# 0.9    24.0
# Name: city08, dtype: double[pyarrow]

# %% [markdown]
# ### Count & Mean of Attribute

# %%
(city_mpg
 .gt(20)
 .sum()
)
# Out:
# 10272

# %%
# (city_mpg
#  .gt(20)
#  .mul(100)
#  .mean()
# )

# %%
(city_mpg
    .gt(20)
    .astype("int64[pyarrow]")   # True/False -> 1/0 en Arrow
    .mul(100)
    .mean()
)
# Out:
# 24.965973167412017

# %% [markdown]
# ### `.agg` & Aggreation Strings

# %%
city_mpg.agg('mean')
# Out:
# 18.369045304297103

# %%
def second_to_last(s):
    return s.iloc[-2]

# %%
city_mpg.agg(['mean', np.var, max, second_to_last])
# Out:
# /var/folders/m3/3_zd43kn4nn3q52cpx_b38g00000gn/T/ipykernel_55053/1874248868.py:1: FutureWarning: The provided callable <function var at 0x106cc36d0> is currently using Series.var. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "var" instead.
#   city_mpg.agg(['mean', np.var, max, second_to_last])
# /var/folders/m3/3_zd43kn4nn3q52cpx_b38g00000gn/T/ipykernel_55053/1874248868.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   city_mpg.agg(['mean', np.var, max, second_to_last])
# mean               18.369045
# var                62.503036
# max               150.000000
# second_to_last     18.000000
# Name: city08, dtype: float64

# %% [markdown]
# # Conversion Methods
#
# ### Type Conversion

# %%
city_mpg.astype('int16[pyarrow]')
# Out:
# 0        19
# 1         9
# 2        23
# 3        10
# 4        17
#          ..
# 41139    19
# 41140    20
# 41141    18
# 41142    18
# 41143    16
# Name: city08, Length: 41144, dtype: int16[pyarrow]

# %%
city_mpg.astype('int8[pyarrow]')
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 city_mpg.astype('int8[pyarrow]')
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/internals/blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:179, in astype_array(values, dtype, copy)
#     175     return values
#     177 if not isinstance(values, np.ndarray):
#     178     # i.e. ExtensionArray
# --> 179     values = values.astype(dtype, copy=copy)
#     181 else:
#     182     values = _astype_nansafe(values, dtype, copy=copy)
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/arrays/base.py:710, in ExtensionArray.astype(self, dtype, copy)
#     708 if isinstance(dtype, ExtensionDtype):
#     709     cls = dtype.construct_array_type()
# --> 710     return cls._from_sequence(self, dtype=dtype, copy=copy)
#     712 elif lib.is_np_dtype(dtype, "M"):
#     713     from pandas.core.arrays import DatetimeArray
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py:312, in ArrowExtensionArray._from_sequence(cls, scalars, dtype, copy)
#     308 """
#     309 Construct a new ExtensionArray from a sequence of scalars.
#     310 """
#     311 pa_type = to_pyarrow_type(dtype)
# --> 312 pa_array = cls._box_pa_array(scalars, pa_type=pa_type, copy=copy)
#     313 arr = cls(pa_array)
#     314 return arr
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py:528, in ArrowExtensionArray._box_pa_array(cls, value, pa_type, copy)
#     526 else:
#     527     try:
# --> 528         pa_array = pa_array.cast(pa_type)
#     529     except (
#     530         pa.ArrowInvalid,
#     531         pa.ArrowTypeError,
#     532         pa.ArrowNotImplementedError,
#     533     ):
#     534         if pa.types.is_string(pa_array.type) or pa.types.is_large_string(
#     535             pa_array.type
#     536         ):
#     537             # TODO: Move logic in _from_sequence_of_strings into
#     538             # _box_pa_array
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pyarrow/table.pxi:566, in pyarrow.lib.ChunkedArray.cast()
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pyarrow/compute.py:404, in cast(arr, target_type, safe, options, memory_pool)
#     402     else:
#     403         options = CastOptions.safe(target_type)
# --> 404 return call_function("cast", [arr], options, memory_pool)
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pyarrow/_compute.pyx:590, in pyarrow._compute.call_function()
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pyarrow/_compute.pyx:385, in pyarrow._compute.Function.call()
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pyarrow/error.pxi:154, in pyarrow.lib.pyarrow_internal_check_status()
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pyarrow/error.pxi:91, in pyarrow.lib.check_status()
#
# ArrowInvalid: Integer value 132 not in range: -128 to 127

# %%
np.iinfo('int64')
# Out:
# iinfo(min=-9223372036854775808, max=9223372036854775807, dtype=int64)

# %%
np.iinfo('int8')
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
# np.finfo('int32')

# %% [markdown]
# ### Memory Usage

# %%
city_mpg.nbytes
# Out:
# 329152

# %%
city_mpg.astype('Int16').nbytes
# Out:
# 123432

# %%
make = df.make

# %%
make.nbytes
# Out:
# 425635

# %%
make.memory_usage()
# Out:
# 425763

# %%
make.memory_usage(deep=True)
# Out:
# 425763

# %%
make.astype(str).memory_usage()
# Out:
# 329280

# %%
make.astype(str).memory_usage(deep=True)
# Out:
# 2606395

# %% [markdown]
# ### String & Category Types

# %%
(make
 .astype('category')
 .memory_usage(deep=True)
)
# Out:
# 88697

# %%
(city_mpg
 .astype('category')
 .cat.as_ordered()
)
# Out:
# 0        19
# 1         9
# 2        23
# 3        10
# 4        17
#          ..
# 41139    19
# 41140    20
# 41141    18
# 41142    18
# 41143    16
# Name: city08, Length: 41144, dtype: category
# Categories (105, int64[pyarrow]): [6 < 7 < 8 < 9 ... 137 < 138 < 140 < 150]

# %% [markdown]
# ### Ordered Categories

# %%
values = pd.Series(sorted(set(city_mpg)))

# %%
city_type = pd.CategoricalDtype(
    categories=values,
    ordered=True)

# %%
city_mpg.astype(city_type)
# Out:
# 0        19
# 1         9
# 2        23
# 3        10
# 4        17
#          ..
# 41139    19
# 41140    20
# 41141    18
# 41142    18
# 41143    16
# Name: city08, Length: 41144, dtype: category
# Categories (105, int64): [6 < 7 < 8 < 9 ... 137 < 138 < 140 < 150]

# %%
city_mpg.astype('category').cat.as_ordered()
# Out:
# 0        19
# 1         9
# 2        23
# 3        10
# 4        17
#          ..
# 41139    19
# 41140    20
# 41141    18
# 41142    18
# 41143    16
# Name: city08, Length: 41144, dtype: category
# Categories (105, int64[pyarrow]): [6 < 7 < 8 < 9 ... 137 < 138 < 140 < 150]

# %% [markdown]
# ### Converting to Other Types

# %%
city_mpg.to_frame()
# Out:
#        city08
# 0          19
# 1           9
# 2          23
# 3          10
# 4          17
# ...       ...
# 41139      19
# 41140      20
# 41141      18
# 41142      18
# 41143      16
#
# [41144 rows x 1 columns]

# %% [markdown]
# # Manipulation Methods
#
# ### `.apply & .where`

# %%
def gt20(val):
    return val > 20

# %%
# %%timeit
city_mpg.apply(gt20)
# Out:
# 2.29 ms ± 19.7 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
city_mpg.gt(20)
# Out:
# 28 μs ± 552 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
make = df.make
make
# Out:
# 0        Alfa Romeo
# 1           Ferrari
# 2             Dodge
# 3             Dodge
# 4            Subaru
#             ...
# 41139        Subaru
# 41140        Subaru
# 41141        Subaru
# 41142        Subaru
# 41143        Subaru
# Name: make, Length: 41144, dtype: string[pyarrow]

# %%
make.value_counts()
# Out:
# make
# Chevrolet                           4003
# Ford                                3371
# Dodge                               2583
# GMC                                 2494
# Toyota                              2071
#                                     ...
# Grumman Allied Industries              1
# Environmental Rsch and Devp Corp       1
# General Motors                         1
# Goldacre                               1
# Isis Imports Ltd                       1
# Name: count, Length: 136, dtype: int64[pyarrow]

# %%
top5 = make.value_counts().index[:5]

top5
# Out:
# Index(['Chevrolet', 'Ford', 'Dodge', 'GMC', 'Toyota'], dtype='string[pyarrow]', name='make')

# %%
def generalize_top5(val):
    if val in top5:
        return val
    return 'Other'

# %%
make.apply(generalize_top5)
# Out:
# 0        Other
# 1        Other
# 2        Dodge
# 3        Dodge
# 4        Other
#          ...
# 41139    Other
# 41140    Other
# 41141    Other
# 41142    Other
# 41143    Other
# Name: make, Length: 41144, dtype: object

# %%
make.where(make.isin(top5), other='Other')
# Out:
# 0        Other
# 1        Other
# 2        Dodge
# 3        Dodge
# 4        Other
#          ...
# 41139    Other
# 41140    Other
# 41141    Other
# 41142    Other
# 41143    Other
# Name: make, Length: 41144, dtype: string[pyarrow]

# %%
# %%timeit
make.apply(generalize_top5)
# Out:
# 12.5 ms ± 112 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
make.where(make.isin(top5), 'Other')
# Out:
# 631 μs ± 2.49 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
make.mask(~make.isin(top5), other='Other')
# Out:
# 0        Other
# 1        Other
# 2        Dodge
# 3        Dodge
# 4        Other
#          ...
# 41139    Other
# 41140    Other
# 41141    Other
# 41142    Other
# 41143    Other
# Name: make, Length: 41144, dtype: string[pyarrow]

# %% [markdown]
# ### Apply with NumPy Functions

# %%
# %%timeit
city_mpg.apply(np.log)
# Out:
# 105 μs ± 432 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
city_mpg.apply(math.log)
# Out:
# 2.51 ms ± 5.88 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### `if Else` with Pandas

# %%
vc = make.value_counts()

top5 = vc.index[:5]

top10 = vc.index[:10]

# %%
def generalize(val):
    if val in top5:
        return val
    elif val in top10:
        return 'Top10'
    else:
        return 'Other'

# %%
make.apply(generalize)
# Out:
# 0        Other
# 1        Other
# 2        Dodge
# 3        Dodge
# 4        Other
#          ...
# 41139    Other
# 41140    Other
# 41141    Other
# 41142    Other
# 41143    Other
# Name: make, Length: 41144, dtype: object

# %%
(make
 .case_when(caselist=[(make.isin(top5), make),
                     (make.isin(top10), 'Top10'),
                     (pd.Series(True, index=make.index), 'Other')])
)
# Out:
# 0        Other
# 1        Other
# 2        Dodge
# 3        Dodge
# 4        Other
#          ...
# 41139    Other
# 41140    Other
# 41141    Other
# 41142    Other
# 41143    Other
# Name: make, Length: 41144, dtype: object

# %%
(make
 .where(make.isin(top5), 'Top10')
 .where(make.isin(top10), 'Other')
)
# Out:
# 0        Other
# 1        Other
# 2        Dodge
# 3        Dodge
# 4        Other
#          ...
# 41139    Other
# 41140    Other
# 41141    Other
# 41142    Other
# 41143    Other
# Name: make, Length: 41144, dtype: string[pyarrow]

# %% [markdown]
# ### Missing Data

# %%
cyl = df.cylinders

# %%
(cyl
 .isna()
 .sum()
)
# Out:
# 206

# %%
missing = cyl.isna()

# %%
make.loc[missing]
# Out:
# 7138     Nissan
# 7139     Toyota
# 8143     Toyota
# 8144       Ford
# 8146       Ford
#           ...
# 34563     Tesla
# 34564     Tesla
# 34565     Tesla
# 34566     Tesla
# 34567     Tesla
# Name: make, Length: 206, dtype: string[pyarrow]

# %% [markdown]
# ### Filling In Missing Data

# %%
cyl[cyl.isna()]
# Out:
# 7138     <NA>
# 7139     <NA>
# 8143     <NA>
# 8144     <NA>
# 8146     <NA>
#          ...
# 34563    <NA>
# 34564    <NA>
# 34565    <NA>
# 34566    <NA>
# 34567    <NA>
# Name: cylinders, Length: 206, dtype: int64[pyarrow]

# %%
cyl.fillna(0).loc[7136:7141]
# Out:
# 7136    6
# 7137    6
# 7138    0
# 7139    0
# 7140    6
# 7141    6
# Name: cylinders, dtype: int64[pyarrow]

# %% [markdown]
# ### Interpolating Data

# %%
temp = pd.Series([32, 40, None, 42, 39, 32],
                dtype='float[pyarrow]')

temp
# Out:
# 0    32.0
# 1    40.0
# 2    <NA>
# 3    42.0
# 4    39.0
# 5    32.0
# dtype: float[pyarrow]

# %%
temp.interpolate()
# Out:
# 0    32.0
# 1    40.0
# 2    41.0
# 3    42.0
# 4    39.0
# 5    32.0
# dtype: float[pyarrow]

# %% [markdown]
# ### Clipping Data

# %%
city_mpg.loc[:446]
# Out:
# 0      19
# 1       9
# 2      23
# 3      10
# 4      17
#        ..
# 442    15
# 443    15
# 444    15
# 445    15
# 446    31
# Name: city08, Length: 447, dtype: int64[pyarrow]

# %%
(city_mpg
 .loc[:446]
 .clip(lower=city_mpg.quantile(.05),
       upper=city_mpg.quantile(.95))
)
# Out:
# 0      19
# 1      11
# 2      23
# 3      11
# 4      17
#        ..
# 442    15
# 443    15
# 444    15
# 445    15
# 446    27
# Name: city08, Length: 447, dtype: int64[pyarrow]

# %% [raw]
# result = self
#
# mask = self.isna()

# %% [raw]
# if lower is not None:
#     cond = mask | (self >= lower)
#     result = result.where(
#         cond, lower, inplace=inplace
#     )
# if upper is not None:
#     cond = mask | (self <= upper)
#     result = self if inplace  else result
#     result = result.where(
#         cond, upper, inplace=inplace
#     )
# return result

# %% [markdown]
# ### Sorting Values

# %%
city_mpg.sort_values()
# Out:
# 7901       6
# 21060      6
# 34557      6
# 35887      6
# 37161      6
#         ...
# 34563    138
# 34564    140
# 31256    150
# 32599    150
# 33423    150
# Name: city08, Length: 41144, dtype: int64[pyarrow]

# %%
(city_mpg.sort_values() + highway_mpg) / 2
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 41139    22.5
# 41140    24.0
# 41141    21.0
# 41142    21.0
# 41143    18.5
# Length: 41144, dtype: double[pyarrow]

# %% [markdown]
# ### Sorting The Index

# %%
city_mpg.sort_values().sort_index()
# Out:
# 0        19
# 1         9
# 2        23
# 3        10
# 4        17
#          ..
# 41139    19
# 41140    20
# 41141    18
# 41142    18
# 41143    16
# Name: city08, Length: 41144, dtype: int64[pyarrow]

# %% [markdown]
# ### Dropping Duplicates

# %%
city_mpg.drop_duplicates()
# Out:
# 0         19
# 1          9
# 2         23
# 3         10
# 4         17
#         ...
# 34364    127
# 34409    114
# 34564    140
# 34565    115
# 34566    104
# Name: city08, Length: 105, dtype: int64[pyarrow]

# %% [markdown]
# ### Ranking Data

# %%
city_mpg.rank()
# Out:
# 0        27060.5
# 1          235.5
# 2        35830.0
# 3          607.5
# 4        19484.0
#           ...
# 41139    27060.5
# 41140    29719.5
# 41141    23528.0
# 41142    23528.0
# 41143    15479.0
# Name: city08, Length: 41144, dtype: double[pyarrow]

# %%
city_mpg.rank(method='min')
# Out:
# 0        25555
# 1          136
# 2        35119
# 3          336
# 4        17467
#          ...
# 41139    25555
# 41140    28567
# 41141    21502
# 41142    21502
# 41143    13492
# Name: city08, Length: 41144, dtype: uint64[pyarrow]

# %%
city_mpg.rank(method='dense')
# Out:
# 0        14
# 1         4
# 2        18
# 3         5
# 4        12
#          ..
# 41139    14
# 41140    15
# 41141    13
# 41142    13
# 41143    11
# Name: city08, Length: 41144, dtype: uint64[pyarrow]

# %% [markdown]
# ### Replacing Data

# %%
make.replace('Subaru', 'スバル')
# Out:
# 0        Alfa Romeo
# 1           Ferrari
# 2             Dodge
# 3             Dodge
# 4               スバル
#             ...
# 41139           スバル
# 41140           スバル
# 41141           スバル
# 41142           スバル
# 41143           スバル
# Name: make, Length: 41144, dtype: string[pyarrow]

# %%
make.replace(r'(Fer)ra(r.*)',
   value=r'\2-other-\1', regex=True)
# Out:
# 0          Alfa Romeo
# 1        ri-other-Fer
# 2               Dodge
# 3               Dodge
# 4              Subaru
#              ...
# 41139          Subaru
# 41140          Subaru
# 41141          Subaru
# 41142          Subaru
# 41143          Subaru
# Name: make, Length: 41144, dtype: string[pyarrow]

# %% [markdown]
# ### Binning Data

# %%
pd.cut(city_mpg, 10)
# Out:
# 0        (5.856, 20.4]
# 1        (5.856, 20.4]
# 2         (20.4, 34.8]
# 3        (5.856, 20.4]
# 4        (5.856, 20.4]
#              ...
# 41139    (5.856, 20.4]
# 41140    (5.856, 20.4]
# 41141    (5.856, 20.4]
# 41142    (5.856, 20.4]
# 41143    (5.856, 20.4]
# Name: city08, Length: 41144, dtype: category
# Categories (10, interval[float64, right]): [(5.856, 20.4] < (20.4, 34.8] < (34.8, 49.2] < (49.2, 63.6] ... (92.4, 106.8] < (106.8, 121.2] < (121.2, 135.6] < (135.6, 150.0]]

# %%
pd.cut(city_mpg, [0, 10, 20, 40, 70, 150])
# Out:
# 0        (10, 20]
# 1         (0, 10]
# 2        (20, 40]
# 3         (0, 10]
# 4        (10, 20]
#            ...
# 41139    (10, 20]
# 41140    (10, 20]
# 41141    (10, 20]
# 41142    (10, 20]
# 41143    (10, 20]
# Name: city08, Length: 41144, dtype: category
# Categories (5, interval[int64, right]): [(0, 10] < (10, 20] < (20, 40] < (40, 70] < (70, 150]]

# %%
pd.qcut(city_mpg, 10)
# Out:
# 0         (18.0, 20.0]
# 1        (5.999, 13.0]
# 2         (21.0, 24.0]
# 3        (5.999, 13.0]
# 4         (16.0, 17.0]
#              ...
# 41139     (18.0, 20.0]
# 41140     (18.0, 20.0]
# 41141     (17.0, 18.0]
# 41142     (17.0, 18.0]
# 41143     (15.0, 16.0]
# Name: city08, Length: 41144, dtype: category
# Categories (10, interval[float64, right]): [(5.999, 13.0] < (13.0, 14.0] < (14.0, 15.0] < (15.0, 16.0] ... (18.0, 20.0] < (20.0, 21.0] < (21.0, 24.0] < (24.0, 150.0]]

# %%
pd.qcut(city_mpg, 10, labels=list(range(1, 11)))
# Out:
# 0        7
# 1        1
# 2        9
# 3        1
# 4        5
#         ..
# 41139    7
# 41140    7
# 41141    6
# 41142    6
# 41143    4
# Name: city08, Length: 41144, dtype: category
# Categories (10, int64): [1 < 2 < 3 < 4 ... 7 < 8 < 9 < 10]

# %% [markdown]
# # Indexing Operations
#
# ### Prepping The Data & Renaming The Index

# %%
city2 = city_mpg.rename(make.to_dict())

# %%
city2
# Out:
# Alfa Romeo    19
# Ferrari        9
# Dodge         23
# Dodge         10
# Subaru        17
#               ..
# Subaru        19
# Subaru        20
# Subaru        18
# Subaru        18
# Subaru        16
# Name: city08, Length: 41144, dtype: int64[pyarrow]

# %%
city2.index
# Out:
# Index(['Alfa Romeo', 'Ferrari', 'Dodge', 'Dodge', 'Subaru', 'Subaru', 'Subaru',
#        'Toyota', 'Toyota', 'Toyota',
#        ...
#        'Saab', 'Saturn', 'Saturn', 'Saturn', 'Saturn', 'Subaru', 'Subaru',
#        'Subaru', 'Subaru', 'Subaru'],
#       dtype='object', length=41144)

# %%
city2 = city_mpg.rename(make)

city2
# Out:
# Alfa Romeo    19
# Ferrari        9
# Dodge         23
# Dodge         10
# Subaru        17
#               ..
# Subaru        19
# Subaru        20
# Subaru        18
# Subaru        18
# Subaru        16
# Name: city08, Length: 41144, dtype: int64[pyarrow]

# %%
city2.rename('citympg')
# Out:
# Alfa Romeo    19
# Ferrari        9
# Dodge         23
# Dodge         10
# Subaru        17
#               ..
# Subaru        19
# Subaru        20
# Subaru        18
# Subaru        18
# Subaru        16
# Name: citympg, Length: 41144, dtype: int64[pyarrow]

# %% [markdown]
# #### Resetting Index

# %%
print(city2.reset_index())
# Out:
#             index  city08
# 0      Alfa Romeo      19
# 1         Ferrari       9
# 2           Dodge      23
# 3           Dodge      10
# 4          Subaru      17
# ...           ...     ...
# 41139      Subaru      19
# 41140      Subaru      20
# 41141      Subaru      18
# 41142      Subaru      18
# 41143      Subaru      16
#
# [41144 rows x 2 columns]

# %%
city2.reset_index(drop=True)
# Out:
# 0        19
# 1         9
# 2        23
# 3        10
# 4        17
#          ..
# 41139    19
# 41140    20
# 41141    18
# 41142    18
# 41143    16
# Name: city08, Length: 41144, dtype: int64[pyarrow]

# %% [markdown]
# #### The `.iloc` Attribute

# %%
city2.loc['Subaru']
# Out:
# Subaru    17
# Subaru    21
# Subaru    22
# Subaru    19
# Subaru    20
#           ..
# Subaru    19
# Subaru    20
# Subaru    18
# Subaru    18
# Subaru    16
# Name: city08, Length: 885, dtype: int64[pyarrow]

# %%
city2.loc['Fisker']
# Out:
# 20

# %%
city2.loc[['Fisker']]
# Out:
# Fisker    20
# Name: city08, dtype: int64[pyarrow]

# %%
city2.loc[['Ferrari', 'Lamborghini']]
# Out:
# Ferrari         9
# Ferrari        12
# Ferrari        11
# Ferrari        10
# Ferrari        11
#                ..
# Lamborghini     6
# Lamborghini     8
# Lamborghini     8
# Lamborghini     8
# Lamborghini     8
# Name: city08, Length: 357, dtype: int64[pyarrow]

# %%
city2.loc['Ferrari': 'Lamborghini']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 city2.loc['Ferrari': 'Lamborghini']
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/indexing.py:1411, in _LocIndexer._getitem_axis(self, key, axis)
#    1409 if isinstance(key, slice):
#    1410     self._validate_key(key, axis)
# -> 1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
#    1413     return self._getbool_axis(key, axis=axis)
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/indexing.py:1443, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1440     return obj.copy(deep=False)
#    1442 labels = obj._get_axis(axis)
# -> 1443 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1445 if isinstance(indexer, slice):
#    1446     return self.obj._slice(indexer, axis=axis)
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/indexes/base.py:6708, in Index.slice_indexer(self, start, end, step)
#    6664 def slice_indexer(
#    6665     self,
#    6666     start: Hashable | None = None,
#    6667     end: Hashable | None = None,
#    6668     step: int | None = None,
#    6669 ) -> slice:
#    6670     """
#    6671     Compute the slice indexer for input labels and step.
#    6672
#    (...)
#    6706     slice(1, 3, None)
#    6707     """
# -> 6708     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6710     # return a slice
#    6711     if not is_scalar(start_slice):
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/indexes/base.py:6934, in Index.slice_locs(self, start, end, step)
#    6932 start_slice = None
#    6933 if start is not None:
# -> 6934     start_slice = self.get_slice_bound(start, "left")
#    6935 if start_slice is None:
#    6936     start_slice = 0
#
# File /opt/anaconda3/envs/MTSP/lib/python3.10/site-packages/pandas/core/indexes/base.py:6867, in Index.get_slice_bound(self, label, side)
#    6865     slc = lib.maybe_booleans_to_slice(slc.view("u1"))
#    6866     if isinstance(slc, np.ndarray):
# -> 6867         raise KeyError(
#    6868             f"Cannot get {side} slice bound for non-unique "
#    6869             f"label: {repr(original_label)}"
#    6870         )
#    6872 if isinstance(slc, slice):
#    6873     if side == "left":
#
# KeyError: "Cannot get left slice bound for non-unique label: 'Ferrari'"

# %%
city2.sort_index().loc['Ferrari': 'Lamborghini']

# %%
city2.sort_index().loc["F":"J"]

# %%
idx = pd.Series(['Dodge'])

# %%
city2.loc[idx]

# %%
idx = pd.Series(['Dodge', 'Dodge'])

city2.loc[idx]

# %%
mask = city2 > 50

mask

# %%
city2.loc[mask]

# %%
cost = pd.Series([1.00, 2.25, 3.99, .99, 2.79],
                 index = ['Gum', 'Cookie', 'Melon', 'Roll', 'Carrots'])

# %%
inflation = 1.10

# %%
(cost
    .mul(inflation)
    .loc[lambda s_:s_ > 3]
)

# %%
cost = pd.Series([1.00, 2.25, 3.99, .99, 2.79],
                 index = ['Gum', 'Cookie', 'Melon', 'Roll', 'Carrots'])

inflation = 1.10

# %%
mask = cost >3

# %%
(cost
    .mul(inflation)
    .loc[mask]
)

# %% [markdown]
# #### The `.iloc` Attribute

# %%
city2.iloc[0]

# %%
city2.iloc[-1]

# %%
city2.iloc[[0, 1, -1]]

# %%
city2.iloc[0:5]

# %%
city2.iloc[-8:]

# %%
mask = city2 > 50

# %%
city2.iloc[mask]

# %%
mask = city2 > 50

# %%
city2.iloc[mask.to_numpy()]

# %%
city2.iloc[list(mask)]

# %% [markdown]
# #### Heads & Tails

# %%
city2.head(3)
# Out:
# Alfa Romeo    19
# Ferrari        9
# Dodge         23
# Name: city08, dtype: int64[pyarrow]

# %%
city2.tail(3)
# Out:
# Subaru    18
# Subaru    18
# Subaru    16
# Name: city08, dtype: int64[pyarrow]

# %% [markdown]
# #### Sampling
