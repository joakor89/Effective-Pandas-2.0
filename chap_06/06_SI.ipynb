# %% [markdown]
# # Series Introduction
#
# ### Loading Libraries

# %%
# Numerical Computing
import numpy as np

# Data Manipulation
import pandas as pd

# PyArrow
import pyarrow as pa

# %% [markdown]
# ### A Simple Series Object

# %%
series = {
    'index': [0, 1, 2, 3],
    'data': [145, 142, 38, 13],
    'name': 'songs'
}

# %%
def get(series, idx):
    value_idx = series['index'].index(idx)
    return series['data'][value_idx]

# %%
get(series, 1)
# Out:
# 142

# %% [markdown]
# ### The Index Abstraction

# %%
songs = {
    'index': ['Paul', 'John', 'George', 'Ringo'],
    'data': [145, 142, 38, 13],
    'name': 'counts'
}

# %%
get(songs, 'John')
# Out:
# 142

# %% [markdown]
# #### The `pandas` Series

# %%
songs2 = pd.Series([145, 142, 38, 13],
                   name='counts')

# %%
songs2
# Out:
# 0    145
# 1    142
# 2     38
# 3     13
# Name: counts, dtype: int64

# %%
# On PyArrow
songs3 = pd.Series([145, 142, 38, 13],
                   name='counts', dtype='int64[pyarrow]')

# %%
songs3
# Out:
# 0    145
# 1    142
# 2     38
# 3     13
# Name: counts, dtype: int64[pyarrow]

# %%
songs2.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
songs3 = pd.Series([145, 142, 38, 13],
                   name='counts',
                   index=['Paul', 'John', 'George', 'Ringo'],
                   dtype='int64[pyarrow]')

# %%
songs3
# Out:
# Paul      145
# John      142
# George     38
# Ringo      13
# Name: counts, dtype: int64[pyarrow]

# %%
songs3.index
# Out:
# Index(['Paul', 'John', 'George', 'Ringo'], dtype='str')

# %%
class Foo:
    pass

# %%
ringo = pd.Series(
    ['Richard', 'Starkey', 13, Foo()],
    name='Ringo')

# %%
ringo
# Out:
# 0                                 Richard
# 1                                 Starkey
# 2                                      13
# 3    <__main__.Foo object at 0x13876e950>
# Name: Ringo, dtype: object

# %% [markdown]
# ### The NA Value

# %%
nan_series = pd.Series([2, np.nan],
                        index=['Ono', 'Clapton'])

# %%
nan_series
# Out:
# Ono        2.0
# Clapton    NaN
# dtype: float64

# %%
nan_series2 = pd.Series([2, np.nan],
                        index=['Ono', 'Clapton'], dtype='int64[pyarrow]')

# %%
nan_series2
# Out:
# Ono           2
# Clapton    <NA>
# dtype: int64[pyarrow]

# %%
nan_series2.count()
# Out:
# np.int64(1)

# %%
nan_series2.size
# Out:
# 2

# %% [markdown]
# ### Similar to NumPy

# %%
numpy_ser = np.array([145, 142, 38, 13])

# %%
songs3.iloc[1]
# Out:
# 142

# %%
numpy_ser[1]
# Out:
# np.int64(142)

# %%
songs3.mean()
# Out:
# 84.5

# %%
numpy_ser.mean()
# Out:
# np.float64(84.5)

# %%
len(set(dir(numpy_ser)) & set(dir(songs3)))
# Out:
# 107

# %%
mask = songs3 > songs3.median()

# %%
mask
# Out:
# Paul       True
# John       True
# George    False
# Ringo     False
# Name: counts, dtype: bool[pyarrow]

# %%
songs3[mask]
# Out:
# Paul    145
# John    142
# Name: counts, dtype: int64[pyarrow]

# %%
numpy_ser[numpy_ser > np.median(numpy_ser)]
# Out:
# array([145, 142])

# %% [markdown]
# ### Categorical Data

# %%
s = pd.Series(['s', 'm', 'l'], dtype='category')

# %%
s
# Out:
# 0    s
# 1    m
# 2    l
# dtype: category
# Categories (3, str): ['l', 'm', 's']

# %%
dict_type = pd.ArrowDtype(pa.dictionary(pa.int64(), pa.utf8()))

# %%
s = pd.Series(['m', 'l', 'xs', 's', 'xl'], dtype='dict_type')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 s = pd.Series(['m', 'l', 'xs', 's', 'xl'], dtype='dict_type')
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/series.py:426, in Series.__init__(self, data, index, dtype, name, copy)
#     423     index = ensure_index(index)
#     425 if dtype is not None:
# --> 426     dtype = self._validate_dtype(dtype)
#     428 if data is None:
#     429     index = index if index is not None else default_index(0)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/generic.py:477, in NDFrame._validate_dtype(cls, dtype)
#     475 """validate the passed dtype"""
#     476 if dtype is not None:
# --> 477     dtype = pandas_dtype(dtype)
#     479     # a compound dtype
#     480     if dtype.kind == "V":
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/common.py:1885, in pandas_dtype(dtype)
#    1878     with warnings.catch_warnings():
#    1879         # TODO: warnings.catch_warnings can be removed when numpy>2.3.0
#    1880         # is the minimum version
#    1881         # GH#51523 - Series.astype(np.integer) doesn't show
#    1882         # numpy deprecation warning of np.integer
#    1883         # Hence enabling DeprecationWarning
#    1884         warnings.simplefilter("always", DeprecationWarning)
# -> 1885         npdtype = np.dtype(dtype)
#    1886 except TypeError:
#    1887     raise
#
# TypeError: data type 'dict_type' not understood

# %%
(pd.Series(['sm', 'm', 'l'], dtype='category')
 .rename('size')
 .to_frame()
 .to_feather('/tmp/cat.ft')
)

# %%
# (pd.read_feather('/tmp/cat.ft', dtype='pyarrow')
#  .loc[:, 'size']
#  .dtype
# )

# Fixed Version
(df := pd.read_feather("/tmp/cat.ft", dtype_backend="pyarrow")
).loc[:, "size"].dtype
# Out:
# dictionary<values=large_string, indices=int8, ordered=0>[pyarrow]

# %%
s.cat.ordered
# Out:
# False

# %%
s2 = pd.Series(['m', 'l', 'xs', 's', 'xl'], dtype='string[pyarrow]')

# %%
size_type = pd.CategoricalDtype(
    categories=['s', 'm', 'l'], ordered=True)

# %%
s3 = s2.astype(size_type)
# Out:
# /var/folders/m3/3_zd43kn4nn3q52cpx_b38g00000gn/T/ipykernel_74645/4030792491.py:1: Pandas4Warning: Constructing a Categorical with a dtype and values containing non-null entries not in that dtype's categories is deprecated and will raise in a future version.
#   s3 = s2.astype(size_type)

# %%
s3
# Out:
# 0      m
# 1      l
# 2    NaN
# 3      s
# 4    NaN
# dtype: category
# Categories (3, str): ['s' < 'm' < 'l']

# %%
s3 > 's'
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
s = pd.Series(['s', 'm', 'l'], dtype='category')

# %%
s.cat.reorder_categories(['xs', 's', 'm', 'l', 'xl'], ordered=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 s.cat.reorder_categories(['xs', 's', 'm', 'l', 'xl'], ordered=True)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/accessor.py:127, in PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f(self, *args, **kwargs)
#     125 @functools.wraps(method)
#     126 def f(self, *args, **kwargs):
# --> 127     return self._delegate_method(name, *args, **kwargs)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/arrays/categorical.py:3025, in CategoricalAccessor._delegate_method(self, name, *args, **kwargs)
#    3022 from pandas import Series
#    3024 method = getattr(self._parent, name)
# -> 3025 res = method(*args, **kwargs)
#    3026 if res is not None:
#    3027     return Series(res, index=self._index, name=self._name)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/arrays/categorical.py:1338, in Categorical.reorder_categories(self, new_categories, ordered)
#    1269 """
#    1270 Reorder categories as specified in new_categories.
#    1271
#    (...)   1332                  ordered=True, dtype='category')
#    1333 """
#    1334 if (
#    1335     len(self.categories) != len(new_categories)
#    1336     or not self.categories.difference(new_categories).empty
#    1337 ):
# -> 1338     raise ValueError(
#    1339         "items in new_categories are not the same as in old categories"
#    1340     )
#    1341 return self.set_categories(new_categories, ordered=ordered)
#
# ValueError: items in new_categories are not the same as in old categories

# %%
s.cat.categories
# Out:
# Index(['l', 'm', 's'], dtype='str')

# %%
(s
 .cat.add_categories(['xs', 'xl', ])
 .cat_reorder_categories(['xs', 's', 'm', 'l', 'xl'],
                        ordered=True)
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/m3/3_zd43kn4nn3q52cpx_b38g00000gn/T/ipykernel_74645/1708901390.py in ?()
#       1 (s
#       2  .cat.add_categories(['xs', 'xl', ])
# ----> 3  .cat_reorder_categories(['xs', 's', 'm', 'l', 'xl'],
#       4                         ordered=True)
#       5 )
#
# /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'cat_reorder_categories'
