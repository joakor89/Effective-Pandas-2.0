# %% [markdown]
# # Of Python Types: NumPy & PyArrow (Pandas)
#
# ### Loading Libraries

# %%
# System
import sys

# Numerical Computing
import numpy as np

# Data Manipulation
import pandas as pd

# %% [markdown]
# ### Python Types

# %% [raw]
# int8_t x = 127

# %%
x = 127

# %%
x + 1
# Out:
# 128

# %%
sys.getsizeof(x)
# Out:
# 28

# %% [markdown]
# ### NumPy

# %% [raw]
# int[10];
#
# for (int i = 0; i < 10; i++) {
#     array[i];
# }

# %% [raw]
# for (int i = 0; i < 10; i++) {
#     array[i] += 1;
# }

# %%
array = np.arange(10, dtype='int32')

# %%
array += 1

# %% [raw]
# int main() {
#     int array[10];
#
#     __m256i ones = _mm256_set1_epi32(1);
#     for (int i = 0; i < 10; i += 8) {
#         __m256i vec = _mm256_loadu_si256((__m256i*)&array[i]);
#         vec = _mm256_add_epi32(vec, ones);
#         _mm256_storeu_si256((m256i*)&array[i], vec);
#     }
#     return 0;
# }

# %% [markdown]
# ### Differences in Numpy & Python

# %%
n1 = np.array([1], dtype='uint8')

# %%
n255 = np.array([255], dtype='uint8')

# %%
n1 + n255
# Out:
# array([0], dtype=uint8)

# %%
demo = np.array([1, 2, 3, np.nan])

# %%
demo
# Out:
# array([ 1.,  2.,  3., nan])

# %% [markdown]
# ### Integer Types

# %%
small_values = [1, 99, 127]

large_values = [2**31, 2**63, 2**100]

missing_values = [None, 1, -45]

# %%
small_ser = pd.Series(small_values)

# %%
small_ser
# Out:
# 0      1
# 1     99
# 2    127
# dtype: int64

# %%
small_ser.astype('int8')
# Out:
# 0      1
# 1     99
# 2    127
# dtype: int8

# %%
small_ser = pd.Series(small_values, dtype='int8')
small_ser
# Out:
# 0      1
# 1     99
# 2    127
# dtype: int8

# %%
# With PyArrow
small_ser_pa = pd.Series(small_values, dtype='int8[pyarrow]')
small_ser_pa
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 # With PyArrow
# ----> 2 small_ser_pa = pd.Series(small_values, dtype='int8[pyarrow]')
#       3 small_ser_pa
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/series.py:426, in Series.__init__(self, data, index, dtype, name, copy)
#     423     index = ensure_index(index)
#     425 if dtype is not None:
# --> 426     dtype = self._validate_dtype(dtype)
#     428 if data is None:
#     429     index = index if index is not None else default_index(0)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/generic.py:477, in NDFrame._validate_dtype(cls, dtype)
#     475 """validate the passed dtype"""
#     476 if dtype is not None:
# --> 477     dtype = pandas_dtype(dtype)
#     479     # a compound dtype
#     480     if dtype.kind == "V":
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/common.py:1862, in pandas_dtype(dtype)
#    1859     return StringDtype(na_value=np.nan)
#    1861 # registered extension types
# -> 1862 result = registry.find(dtype)
#    1863 if result is not None:
#    1864     if isinstance(result, type):
#    1865         # GH 31356, GH 54592
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/base.py:590, in Registry.find(self, dtype)
#     588 for dtype_type in self.dtypes:
#     589     try:
# --> 590         return dtype_type.construct_from_string(dtype)
#     591     except TypeError:
#     592         pass
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/dtypes.py:2377, in ArrowDtype.construct_from_string(cls, string)
#    2375     raise TypeError("string[pyarrow] should be constructed by StringDtype")
#    2376 if not HAS_PYARROW:
# -> 2377     raise ImportError(
#    2378         f"pyarrow>={PYARROW_MIN_VERSION} is required for ArrowDtype"
#    2379     )
#    2381 base_type = string[:-9]  # get rid of "[pyarrow]"
#    2382 try:
#
# ImportError: pyarrow>=13.0.0 is required for ArrowDtype

# %%
larger_ser = pd.Series(large_values)
larger_ser
# Out:
# 0                         2147483648
# 1                9223372036854775808
# 2    1267650600228229401496703205376
# dtype: object

# %%
larger_ser = pd.Series(larger_ser, dtype='int64[pyarrow]')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 larger_ser = pd.Series(larger_ser, dtype='int64[pyarrow]')
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/series.py:426, in Series.__init__(self, data, index, dtype, name, copy)
#     423     index = ensure_index(index)
#     425 if dtype is not None:
# --> 426     dtype = self._validate_dtype(dtype)
#     428 if data is None:
#     429     index = index if index is not None else default_index(0)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/generic.py:477, in NDFrame._validate_dtype(cls, dtype)
#     475 """validate the passed dtype"""
#     476 if dtype is not None:
# --> 477     dtype = pandas_dtype(dtype)
#     479     # a compound dtype
#     480     if dtype.kind == "V":
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/common.py:1862, in pandas_dtype(dtype)
#    1859     return StringDtype(na_value=np.nan)
#    1861 # registered extension types
# -> 1862 result = registry.find(dtype)
#    1863 if result is not None:
#    1864     if isinstance(result, type):
#    1865         # GH 31356, GH 54592
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/base.py:590, in Registry.find(self, dtype)
#     588 for dtype_type in self.dtypes:
#     589     try:
# --> 590         return dtype_type.construct_from_string(dtype)
#     591     except TypeError:
#     592         pass
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/dtypes.py:2377, in ArrowDtype.construct_from_string(cls, string)
#    2375     raise TypeError("string[pyarrow] should be constructed by StringDtype")
#    2376 if not HAS_PYARROW:
# -> 2377     raise ImportError(
#    2378         f"pyarrow>={PYARROW_MIN_VERSION} is required for ArrowDtype"
#    2379     )
#    2381 base_type = string[:-9]  # get rid of "[pyarrow]"
#    2382 try:
#
# ImportError: pyarrow>=13.0.0 is required for ArrowDtype

# %%
missing_ser = pd.Series(missing_values)
missing_ser
# Out:
# 0     NaN
# 1     1.0
# 2   -45.0
# dtype: float64

# %%
missing_ser_pa = pd.Series(missing_values, dtype='int8[pyarrow]')
missing_ser_pa
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 missing_ser_pa = pd.Series(missing_values, dtype='int8[pyarrow]')
#       2 missing_ser_pa
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/series.py:426, in Series.__init__(self, data, index, dtype, name, copy)
#     423     index = ensure_index(index)
#     425 if dtype is not None:
# --> 426     dtype = self._validate_dtype(dtype)
#     428 if data is None:
#     429     index = index if index is not None else default_index(0)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/generic.py:477, in NDFrame._validate_dtype(cls, dtype)
#     475 """validate the passed dtype"""
#     476 if dtype is not None:
# --> 477     dtype = pandas_dtype(dtype)
#     479     # a compound dtype
#     480     if dtype.kind == "V":
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/common.py:1862, in pandas_dtype(dtype)
#    1859     return StringDtype(na_value=np.nan)
#    1861 # registered extension types
# -> 1862 result = registry.find(dtype)
#    1863 if result is not None:
#    1864     if isinstance(result, type):
#    1865         # GH 31356, GH 54592
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/base.py:590, in Registry.find(self, dtype)
#     588 for dtype_type in self.dtypes:
#     589     try:
# --> 590         return dtype_type.construct_from_string(dtype)
#     591     except TypeError:
#     592         pass
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/dtypes.py:2377, in ArrowDtype.construct_from_string(cls, string)
#    2375     raise TypeError("string[pyarrow] should be constructed by StringDtype")
#    2376 if not HAS_PYARROW:
# -> 2377     raise ImportError(
#    2378         f"pyarrow>={PYARROW_MIN_VERSION} is required for ArrowDtype"
#    2379     )
#    2381 base_type = string[:-9]  # get rid of "[pyarrow]"
#    2382 try:
#
# ImportError: pyarrow>=13.0.0 is required for ArrowDtype

# %%
medium_values = [2**15+5, 2**31-8, 2**63]

medium_ser = pd.Series(medium_values)
medium_ser
# Out:
# 0                  32773
# 1             2147483640
# 2    9223372036854775808
# dtype: uint64

# %%
medium_ser.astype('int8')
# Out:
# 0    5
# 1   -8
# 2    0
# dtype: int8

# %%
medium_ser.astype('int8[pyarrow]')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 medium_ser.astype('int8[pyarrow]')
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/generic.py:6528, in NDFrame.astype(self, dtype, copy, errors)
#    6525                 raise
#    6526         results.append(res_col)
# -> 6528 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    6529     # TODO(EA2D): special case not needed with 2D EAs
#    6530     dtype = pandas_dtype(dtype)
#    6531     if isinstance(dtype, ExtensionDtype) and all(
#    6532         block.values.dtype == dtype for block in self._mgr.blocks
#    6533     ):
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/common.py:1540, in is_extension_array_dtype(arr_or_dtype)
#    1537     with warnings.catch_warnings():
#    1538         # pandas_dtype(..) can raise UserWarning for class input
#    1539         warnings.simplefilter("ignore", UserWarning)
# -> 1540         dtype = pandas_dtype(dtype)
#    1541 except (TypeError, ValueError):
#    1542     # np.dtype(..) can raise ValueError
#    1543     return False
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/common.py:1862, in pandas_dtype(dtype)
#    1859     return StringDtype(na_value=np.nan)
#    1861 # registered extension types
# -> 1862 result = registry.find(dtype)
#    1863 if result is not None:
#    1864     if isinstance(result, type):
#    1865         # GH 31356, GH 54592
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/base.py:590, in Registry.find(self, dtype)
#     588 for dtype_type in self.dtypes:
#     589     try:
# --> 590         return dtype_type.construct_from_string(dtype)
#     591     except TypeError:
#     592         pass
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/dtypes.py:2377, in ArrowDtype.construct_from_string(cls, string)
#    2375     raise TypeError("string[pyarrow] should be constructed by StringDtype")
#    2376 if not HAS_PYARROW:
# -> 2377     raise ImportError(
#    2378         f"pyarrow>={PYARROW_MIN_VERSION} is required for ArrowDtype"
#    2379     )
#    2381 base_type = string[:-9]  # get rid of "[pyarrow]"
#    2382 try:
#
# ImportError: pyarrow>=13.0.0 is required for ArrowDtype

# %%
### Floating Point Types
