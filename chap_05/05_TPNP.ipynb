# %% [markdown]
# # Of Python Types: NumPy & PyArrow (Pandas)
#
# ### Loading Libraries

# %%
# System
import sys

# Numerical Computing
import numpy as np

# Data Manipulation
import pandas as pd

# %% [markdown]
# ### Python Types

# %% [raw]
# int8_t x = 127

# %%
x = 127

# %%
x + 1
# Out:
# 128

# %%
sys.getsizeof(x)
# Out:
# 28

# %% [markdown]
# ### NumPy

# %% [raw]
# int[10];
#
# for (int i = 0; i < 10; i++) {
#     array[i];
# }

# %% [raw]
# for (int i = 0; i < 10; i++) {
#     array[i] += 1;
# }

# %%
array = np.arange(10, dtype='int32')

# %%
array += 1

# %% [raw]
# int main() {
#     int array[10];
#
#     __m256i ones = _mm256_set1_epi32(1);
#     for (int i = 0; i < 10; i += 8) {
#         __m256i vec = _mm256_loadu_si256((__m256i*)&array[i]);
#         vec = _mm256_add_epi32(vec, ones);
#         _mm256_storeu_si256((m256i*)&array[i], vec);
#     }
#     return 0;
# }

# %% [markdown]
# ### Differences in Numpy & Python

# %%
n1 = np.array([1], dtype='uint8')

# %%
n255 = np.array([255], dtype='uint8')

# %%
n1 + n255
# Out:
# array([0], dtype=uint8)

# %%
demo = np.array([1, 2, 3, np.nan])

# %%
demo
# Out:
# array([ 1.,  2.,  3., nan])

# %% [markdown]
# ### Integer Types

# %%
small_values = [1, 99, 127]

large_values = [2**31, 2**63, 2**100]

missing_values = [None, 1, -45]

# %%
small_ser = pd.Series(small_values)

# %%
small_ser
# Out:
# 0      1
# 1     99
# 2    127
# dtype: int64

# %%
small_ser.astype('int8')
# Out:
# 0      1
# 1     99
# 2    127
# dtype: int8

# %%
small_ser = pd.Series(small_values, dtype='int8')
small_ser
# Out:
# 0      1
# 1     99
# 2    127
# dtype: int8

# %%
# With PyArrow
small_ser_pa = pd.Series(small_values, dtype='int8[pyarrow]')
small_ser_pa
# Out:
# 0      1
# 1     99
# 2    127
# dtype: int8[pyarrow]

# %%
larger_ser = pd.Series(large_values)
larger_ser
# Out:
# 0                         2147483648
# 1                9223372036854775808
# 2    1267650600228229401496703205376
# dtype: object

# %%
larger_ser = pd.Series(larger_ser, dtype='int64[pyarrow]')
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 larger_ser = pd.Series(larger_ser, dtype='int64[pyarrow]')
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/series.py:510, in Series.__init__(self, data, index, dtype, name, copy)
#     508     if not astype_is_view(data.dtype, pandas_dtype(dtype)):
#     509         copy = False
# --> 510     data = data.astype(dtype=dtype)
#     511 if copy:
#     512     data = data.copy(deep=True)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/internals/managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/internals/managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:185, in astype_array(values, dtype, copy)
#     182     values = values.astype(dtype, copy=copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#     188 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:81, in _astype_nansafe(arr, dtype, copy, skipna)
#      79 # dispatch on extension dtype if needed
#      80 if isinstance(dtype, ExtensionDtype):
# ---> 81     return dtype.construct_array_type()._from_sequence(arr, dtype=dtype, copy=copy)
#      83 elif not isinstance(dtype, np.dtype):  # pragma: no cover
#      84     raise ValueError("dtype must be np.dtype or ExtensionDtype")
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py:333, in ArrowExtensionArray._from_sequence(cls, scalars, dtype, copy)
#     329 """
#     330 Construct a new ExtensionArray from a sequence of scalars.
#     331 """
#     332 pa_type = to_pyarrow_type(dtype)
# --> 333 pa_array = cls._box_pa_array(scalars, pa_type=pa_type, copy=copy)
#     334 arr = cls(pa_array)
#     335 return arr
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py:676, in ArrowExtensionArray._box_pa_array(cls, value, pa_type, copy)
#     673     mask = is_pdna_or_none(arr_value)
#     675 try:
# --> 676     pa_array = pa.array(value, type=pa_type, mask=mask)
#     677 except (pa.ArrowInvalid, pa.ArrowTypeError):
#     678     # GH50430: let pyarrow infer type, then cast
#     679     pa_array = pa.array(value, mask=mask)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/array.pxi:365, in pyarrow.lib.array()
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/array.pxi:91, in pyarrow.lib._ndarray_to_array()
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/error.pxi:89, in pyarrow.lib.check_status()
#
# OverflowError: Python int too large to convert to C long

# %%
missing_ser = pd.Series(missing_values)
missing_ser
# Out:
# 0     NaN
# 1     1.0
# 2   -45.0
# dtype: float64

# %%
missing_ser_pa = pd.Series(missing_values, dtype='int8[pyarrow]')
missing_ser_pa
# Out:
# 0    <NA>
# 1       1
# 2     -45
# dtype: int8[pyarrow]

# %%
medium_values = [2**15+5, 2**31-8, 2**63]

medium_ser = pd.Series(medium_values)
medium_ser
# Out:
# 0                  32773
# 1             2147483640
# 2    9223372036854775808
# dtype: uint64

# %%
medium_ser.astype('int8')
# Out:
# 0    5
# 1   -8
# 2    0
# dtype: int8

# %%
medium_ser.astype('int8[pyarrow]')
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 medium_ser.astype('int8[pyarrow]')
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/internals/managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/internals/managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:185, in astype_array(values, dtype, copy)
#     182     values = values.astype(dtype, copy=copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#     188 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:81, in _astype_nansafe(arr, dtype, copy, skipna)
#      79 # dispatch on extension dtype if needed
#      80 if isinstance(dtype, ExtensionDtype):
# ---> 81     return dtype.construct_array_type()._from_sequence(arr, dtype=dtype, copy=copy)
#      83 elif not isinstance(dtype, np.dtype):  # pragma: no cover
#      84     raise ValueError("dtype must be np.dtype or ExtensionDtype")
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py:333, in ArrowExtensionArray._from_sequence(cls, scalars, dtype, copy)
#     329 """
#     330 Construct a new ExtensionArray from a sequence of scalars.
#     331 """
#     332 pa_type = to_pyarrow_type(dtype)
# --> 333 pa_array = cls._box_pa_array(scalars, pa_type=pa_type, copy=copy)
#     334 arr = cls(pa_array)
#     335 return arr
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py:704, in ArrowExtensionArray._box_pa_array(cls, value, pa_type, copy)
#     702 else:
#     703     try:
# --> 704         pa_array = pa_array.cast(pa_type)
#     705     except (pa.ArrowNotImplementedError, pa.ArrowTypeError):
#     706         if pa.types.is_string(pa_array.type) or pa.types.is_large_string(
#     707             pa_array.type
#     708         ):
#     709             # TODO: Move logic in _from_sequence_of_strings into
#     710             # _box_pa_array
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/array.pxi:1135, in pyarrow.lib.Array.cast()
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/compute.py:412, in cast(arr, target_type, safe, options, memory_pool)
#     410     else:
#     411         options = CastOptions.safe(target_type)
# --> 412 return call_function("cast", [arr], options, memory_pool)
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/_compute.pyx:604, in pyarrow._compute.call_function()
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/_compute.pyx:399, in pyarrow._compute.Function.call()
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File /opt/anaconda3/envs/EP2/lib/python3.11/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: Integer value 32773 not in range: 0 to 127

# %% [markdown]
# ### Floating Point Types

# %%
float_vals = [1.5, 2.7, 127.0]

float_missing = [None, 1.5, -45.0]

float_rain = [1.5, 2.7, 0.0, 'T', 1.5, 0]

# %%
pd.Series(float_vals)
# Out:
# 0      1.5
# 1      2.7
# 2    127.0
# dtype: float64

# %%
pd.Series(float_missing)
# Out:
# 0     NaN
# 1     1.5
# 2   -45.0
# dtype: float64

# %%
pd.Series(float_vals, dtype='float64[pyarrow]')
# Out:
# 0      1.5
# 1      2.7
# 2    127.0
# dtype: double[pyarrow]

# %%
pd.Series(float_missing, dtype='float64[pyarrow]')
# Out:
# 0    <NA>
# 1     1.5
# 2   -45.0
# dtype: double[pyarrow]

# %%
pd.Series(float_rain)
# Out:
# 0    1.5
# 1    2.7
# 2    0.0
# 3      T
# 4    1.5
# 5      0
# dtype: object

# %%
pd.Series(float_rain).replace('T', '0.0').astype('float64')
# Out:
# 0    1.5
# 1    2.7
# 2    0.0
# 3    0.0
# 4    1.5
# 5    0.0
# dtype: float64

# %%
pd.Series(float_rain).replace('T', 0).astype('float64[pyarrow]')
# Out:
# 0    1.5
# 1    2.7
# 2    0.0
# 3    0.0
# 4    1.5
# 5    0.0
# dtype: double[pyarrow]

# %%
(pd.Series(float_rain)
    .replace('T', 0)
    .astype('float64[pyarrow]')
)
# Out:
# 0    1.5
# 1    2.7
# 2    0.0
# 3    0.0
# 4    1.5
# 5    0.0
# dtype: double[pyarrow]

# %%
### String Data
