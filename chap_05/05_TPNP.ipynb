# %% [markdown]
# # Of Python Types: NumPy & PyArrow (Pandas)
#
# ### Loading Libraries

# %%
# System
import sys

# Numerical Computing
import numpy as np

# Data Manipulation
import pandas as pd

# %% [markdown]
# ### Python Types

# %% [markdown]
# ##### int8_t x = 127

# %%
x = 127

# %%
x + 1
# Out:
# 128

# %%
sys.getsizeof(x)
# Out:
# 28

# %%
###
